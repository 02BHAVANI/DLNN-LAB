# %%
# Import necessary libraries
import kagglehub
import numpy as np
import matplotlib.pyplot as plt
import cv2
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import img_to_array

# %%
# Download the dataset
path = kagglehub.dataset_download("atulanandjha/lfwpeople")
print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.4)
# Downloading from https://www.kaggle.com/api/v1/datasets/download/atulanandjha/lfwpeople?dataset_version_number=3...
# 100%|██████████| 232M/232M [00:02<00:00, 116MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/atulanandjha/lfwpeople/versions/3

# %%
import os

# List the contents of the main path directory
print("Contents of main dataset path:")
for item in os.listdir(path):
    item_path = os.path.join(path, item)
    if os.path.isdir(item_path):
        print(f"Directory: {item}")
    else:
        print(f"File: {item}")
# Out:
# Contents of main dataset path:
# File: pairsDevTest.txt
# Directory: lfw_funneled
# File: pairsDevTrain.txt
# File: pairs.txt
# File: lfw-funneled.tgz

# %%
# Verify the structure within the lfw_funneled directory
verify_directory_structure(os.path.join(path, "lfw_funneled"))
# Out:
# Streaming output truncated to the last 5000 lines.
# Found label directory: Harrison_Ford
#   Images found in Harrison_Ford: 12
# Found label directory: Lazaro_Castro
#   Images found in Lazaro_Castro: 1
# Found label directory: Daniel_Chin
#   Images found in Daniel_Chin: 1
# Found label directory: Tex_Ritter
#   Images found in Tex_Ritter: 1
# Found label directory: Paul-Henri_Mathieu
#   Images found in Paul-Henri_Mathieu: 3
# Found label directory: Brandon_Robinson
#   Images found in Brandon_Robinson: 1
# Found label directory: Bing_Crosby
#   Images found in Bing_Crosby: 1
# Found label directory: Sandra_Banning
#   Images found in Sandra_Banning: 1
# Found label directory: Baz_Luhrmann
#   Images found in Baz_Luhrmann: 1
# Found label directory: Shania_Twain
#   Images found in Shania_Twain: 1
# Warning: pairs_09.txt is not a directory
# Found label directory: Nicole_Kidman
#   Images found in Nicole_Kidman: 19
# Found label directory: Leszek_Miller
#   Images found in Leszek_Miller: 3
# Found label directory: William_Hochul
#   Images found in William_Hochul: 2
# Found label directory: Carlos_Bianchi
#   Images found in Carlos_Bianchi: 2
# Found label directory: Reinhard_Buetikofer
#   Images found in Reinhard_Buetikofer: 1
# Found label directory: Juan_Manuel_Marquez
#   Images found in Juan_Manuel_Marquez: 3
# Found label directory: Damarius_Bilbo
#   Images found in Damarius_Bilbo: 1
# Found label directory: Justine_Henin
#   Images found in Justine_Henin: 3
# Found label directory: Mahdi_Al_Bassam
#   Images found in Mahdi_Al_Bassam: 1
# Found label directory: Eddy_Hartenstein
#   Images found in Eddy_Hartenstein: 1
# Found label directory: Tim_Curley
#   Images found in Tim_Curley: 1
# Found label directory: Hermando_Harton
#   Images found in Hermando_Harton: 1
# Found label directory: David_Ballantyne
#   Images found in David_Ballantyne: 1
# Found label directory: Tom_Kelly
#   Images found in Tom_Kelly: 1
# Found label directory: Yukiko_Okudo
#   Images found in Yukiko_Okudo: 2
# Found label directory: Zorica_Radovic
#   Images found in Zorica_Radovic: 1
# Found label directory: John_McCormack
#   Images found in John_McCormack: 2
# Found label directory: Daniel_Scioli
#   Images found in Daniel_Scioli: 1
# Found label directory: John_Gruden
#   Images found in John_Gruden: 1
# Found label directory: Marcos_Milinkovic
#   Images found in Marcos_Milinkovic: 1
# Found label directory: Diane_Green
#   Images found in Diane_Green: 2
# Found label directory: David_Suazo
#   Images found in David_Suazo: 1
# Found label directory: Taia_Balk
#   Images found in Taia_Balk: 1
# Found label directory: Ramon_Ponce_de_Leon
#   Images found in Ramon_Ponce_de_Leon: 1
# Found label directory: Robert_McKee
#   Images found in Robert_McKee: 1
# Found label directory: Ratna_Sari_Dewi_Sukarno
#   Images found in Ratna_Sari_Dewi_Sukarno: 1
# Found label directory: Bob_Wright
#   Images found in Bob_Wright: 1
# Found label directory: Mikhail_Kasyanov
#   Images found in Mikhail_Kasyanov: 4
# Found label directory: Carson_Palmer
#   Images found in Carson_Palmer: 4
# Found label directory: James_Mathis
#   Images found in James_Mathis: 1
# Found label directory: Eric_Snow
#   Images found in Eric_Snow: 1
# Found label directory: Eric_Idle
#   Images found in Eric_Idle: 1
# Found label directory: Lili_Taylor
#   Images found in Lili_Taylor: 2
# Found label directory: Nate_Hybl
#   Images found in Nate_Hybl: 1
# Found label directory: Paul_Sarbanes
#   Images found in Paul_Sarbanes: 3
# Found label directory: Carroll_Weimer
#   Images found in Carroll_Weimer: 1
# Found label directory: Dariusz_Michalczewski
#   Images found in Dariusz_Michalczewski: 1
# Found label directory: Jean-Marc_de_La_Sabliere
#   Images found in Jean-Marc_de_La_Sabliere: 2
# Found label directory: Stephen_Arigbabu
#   Images found in Stephen_Arigbabu: 1
# Found label directory: Nick_Reilly
#   Images found in Nick_Reilly: 1
# Found label directory: Hrithik_Roshan
#   Images found in Hrithik_Roshan: 1
# Found label directory: Keanu_Reeves
#   Images found in Keanu_Reeves: 12
# Found label directory: Hee-Won_Han
#   Images found in Hee-Won_Han: 3
# Found label directory: Dave_Robertson
#   Images found in Dave_Robertson: 1
# Found label directory: Aron_Ralston
#   Images found in Aron_Ralston: 2
# Found label directory: Vincent_Brooks
#   Images found in Vincent_Brooks: 7
# Found label directory: Tracee_Treadwell
#   Images found in Tracee_Treadwell: 1
# Found label directory: Adam_Kennedy
#   Images found in Adam_Kennedy: 1
# Found label directory: Gary_Bald
#   Images found in Gary_Bald: 1
# Found label directory: Brian_Cashman
#   Images found in Brian_Cashman: 1
# Found label directory: Prince_Rainier_III
#   Images found in Prince_Rainier_III: 1
# Found label directory: Lorraine_Fenton
#   Images found in Lorraine_Fenton: 1
# Found label directory: Janice_Abreu
#   Images found in Janice_Abreu: 1
# Found label directory: Carlos_De_Abreu
#   Images found in Carlos_De_Abreu: 1
# Found label directory: Lou_Piniella
#   Images found in Lou_Piniella: 3
# Found label directory: Brian_De_Palma
#   Images found in Brian_De_Palma: 1
# Found label directory: Paul_Wilson
#   Images found in Paul_Wilson: 1
# Found label directory: Brendan_Gaughan
#   Images found in Brendan_Gaughan: 1
# Found label directory: Rogerio_Romero
#   Images found in Rogerio_Romero: 2
# Found label directory: Nancy_Smith
#   Images found in Nancy_Smith: 1
# Found label directory: Craig_Morgan
#   Images found in Craig_Morgan: 1
# Found label directory: Mary_Landrieu
#   Images found in Mary_Landrieu: 3
# Found label directory: Carlos_Alberto
#   Images found in Carlos_Alberto: 1
# Found label directory: Bernard_Ebbers
#   Images found in Bernard_Ebbers: 1
# Found label directory: Joey_Harrington
#   Images found in Joey_Harrington: 1
# Found label directory: Bijan_Darvish
#   Images found in Bijan_Darvish: 3
# Found label directory: Kenneth_Carlsen
#   Images found in Kenneth_Carlsen: 1
# Found label directory: John_Lennon
#   Images found in John_Lennon: 1
# Found label directory: John_Taylor
#   Images found in John_Taylor: 2
# Found label directory: Bob_Beauprez
#   Images found in Bob_Beauprez: 2
# Found label directory: Rogelio_Montemayor
#   Images found in Rogelio_Montemayor: 1
# Found label directory: Don_Boudria
#   Images found in Don_Boudria: 1
# Found label directory: Jack_Goodman
#   Images found in Jack_Goodman: 1
# Found label directory: Carolyn_Dawn_Johnson
#   Images found in Carolyn_Dawn_Johnson: 3
# Found label directory: Bill_Butler
#   Images found in Bill_Butler: 1
# Found label directory: Marcelo_Rios
#   Images found in Marcelo_Rios: 5
# Found label directory: Fann_Wong
#   Images found in Fann_Wong: 1
# Found label directory: Pa_Kou_Hang
#   Images found in Pa_Kou_Hang: 1
# Found label directory: Eric_Taino
#   Images found in Eric_Taino: 1
# Found label directory: Ontario_Lett
#   Images found in Ontario_Lett: 1
# Found label directory: Joe_Metz
#   Images found in Joe_Metz: 1
# Found label directory: Brooke_Adams
#   Images found in Brooke_Adams: 1
# Found label directory: Mark_Wahlberg
#   Images found in Mark_Wahlberg: 4
# Found label directory: Margaret_Hoelzer
#   Images found in Margaret_Hoelzer: 1
# Found label directory: Mark_Mariscal
#   Images found in Mark_Mariscal: 1
# Found label directory: John_Ruiz
#   Images found in John_Ruiz: 2
# Found label directory: Ali_Naimi
#   Images found in Ali_Naimi: 8
# Found label directory: Penelope_Taylor
#   Images found in Penelope_Taylor: 1
# Found label directory: Paul_Schrader
#   Images found in Paul_Schrader: 1
# Found label directory: Pat_Riley
#   Images found in Pat_Riley: 1
# Found label directory: Phil_Donahue
#   Images found in Phil_Donahue: 1
# Found label directory: Henry_Hilow
#   Images found in Henry_Hilow: 1
# Found label directory: Mariangel_Ruiz_Torrealba
#   Images found in Mariangel_Ruiz_Torrealba: 3
# Found label directory: Joe_Dumars
#   Images found in Joe_Dumars: 2
# Found label directory: Wendell_Bryant
#   Images found in Wendell_Bryant: 1
# Found label directory: Gianni_Agnelli
#   Images found in Gianni_Agnelli: 1
# Found label directory: Rod_Paige
#   Images found in Rod_Paige: 1
# Found label directory: Cruz_Bustamante
#   Images found in Cruz_Bustamante: 5
# Found label directory: Lynne_Thigpen
#   Images found in Lynne_Thigpen: 1
# Found label directory: Gloria_Allred
#   Images found in Gloria_Allred: 2
# Found label directory: William_Genego
#   Images found in William_Genego: 1
# Found label directory: Tammy_Helm
#   Images found in Tammy_Helm: 1
# Found label directory: Eriko_Tamura
#   Images found in Eriko_Tamura: 1
# Found label directory: Betty_Williams
#   Images found in Betty_Williams: 1
# Found label directory: TJ_Ford
#   Images found in TJ_Ford: 1
# Found label directory: Donald_Carty
#   Images found in Donald_Carty: 1
# Found label directory: John_Blaney
#   Images found in John_Blaney: 2
# Found label directory: Lucy_Liu
#   Images found in Lucy_Liu: 5
# Found label directory: Howard_Stern
#   Images found in Howard_Stern: 1
# Found label directory: Katie_Couric
#   Images found in Katie_Couric: 1
# Found label directory: Patrice_Chereau
#   Images found in Patrice_Chereau: 2
# Found label directory: Doug_Collins
#   Images found in Doug_Collins: 2
# Found label directory: Rob_Lowe
#   Images found in Rob_Lowe: 4
# Found label directory: Bob_Melvin
#   Images found in Bob_Melvin: 1
# Found label directory: Kenenisa_Bekele
#   Images found in Kenenisa_Bekele: 1
# Found label directory: Crandall_Bowles
#   Images found in Crandall_Bowles: 1
# Found label directory: Edouard_Michelin
#   Images found in Edouard_Michelin: 1
# Found label directory: Mitchell_Potter
#   Images found in Mitchell_Potter: 1
# Found label directory: Niall_Connolly
#   Images found in Niall_Connolly: 1
# Found label directory: Randy_Brown
#   Images found in Randy_Brown: 1
# Found label directory: Cassandra_Heise
#   Images found in Cassandra_Heise: 1
# Found label directory: Ali_Hammoud
#   Images found in Ali_Hammoud: 1
# Found label directory: David_Dewhurst
#   Images found in David_Dewhurst: 1
# Found label directory: Lynn_Redgrave
#   Images found in Lynn_Redgrave: 3
# Found label directory: Richard_Sambrook
#   Images found in Richard_Sambrook: 2
# Found label directory: Alain_Cervantes
#   Images found in Alain_Cervantes: 1
# Found label directory: John_Walsh
#   Images found in John_Walsh: 2
# Found label directory: Jay_Rasulo
#   Images found in Jay_Rasulo: 2
# Found label directory: Andrew_Firestone
#   Images found in Andrew_Firestone: 1
# Found label directory: Elmar_Brok
#   Images found in Elmar_Brok: 1
# Found label directory: Dereck_Whittenburg
#   Images found in Dereck_Whittenburg: 1
# Found label directory: Chok_Tong_Goh
#   Images found in Chok_Tong_Goh: 2
# Found label directory: Norm_Coleman
#   Images found in Norm_Coleman: 7
# Found label directory: Adam_Freier
#   Images found in Adam_Freier: 1
# Found label directory: Charlie_Garner
#   Images found in Charlie_Garner: 1
# Found label directory: Wang_Yingfan
#   Images found in Wang_Yingfan: 3
# Found label directory: Xiang_Xu
#   Images found in Xiang_Xu: 1
# Found label directory: Mia_Mottley
#   Images found in Mia_Mottley: 1
# Found label directory: Stephen_Covey
#   Images found in Stephen_Covey: 1
# Found label directory: Milton_Berle
#   Images found in Milton_Berle: 1
# Found label directory: Dave_Odom
#   Images found in Dave_Odom: 1
# Found label directory: James_McMahon
#   Images found in James_McMahon: 1
# Found label directory: Sue_Grafton
#   Images found in Sue_Grafton: 1
# Found label directory: James_Collinson
#   Images found in James_Collinson: 1
# Found label directory: Oswald_Gruebel
#   Images found in Oswald_Gruebel: 1
# Found label directory: Robert_Blackwill
#   Images found in Robert_Blackwill: 2
# Found label directory: Colin_Powell
#   Images found in Colin_Powell: 236
# Found label directory: Mohammed_Abulhasan
#   Images found in Mohammed_Abulhasan: 1
# Found label directory: Mireille_Jospin-Dandieu
#   Images found in Mireille_Jospin-Dandieu: 1
# Found label directory: Itamar_Franco
#   Images found in Itamar_Franco: 1
# Found label directory: Lisa_Leslie
#   Images found in Lisa_Leslie: 1
# Found label directory: Rick_Bland
#   Images found in Rick_Bland: 1
# Found label directory: Luis_Fonsi
#   Images found in Luis_Fonsi: 1
# Found label directory: Yasar_Yakis
#   Images found in Yasar_Yakis: 4
# Found label directory: Syed_Abdul_Rahman_Geelani
#   Images found in Syed_Abdul_Rahman_Geelani: 1
# Found label directory: Mark_Rosenbaum
#   Images found in Mark_Rosenbaum: 1
# Found label directory: William_Ford_Jr
#   Images found in William_Ford_Jr: 7
# Found label directory: Sherry_Irving
#   Images found in Sherry_Irving: 1
# Found label directory: Mariam_Ali_Hassan
#   Images found in Mariam_Ali_Hassan: 1
# Found label directory: Ramiro_Goben_Reducindo
#   Images found in Ramiro_Goben_Reducindo: 1
# Found label directory: Rod_Blagojevich
#   Images found in Rod_Blagojevich: 2
# Found label directory: David_Dewayne_Williams
#   Images found in David_Dewayne_Williams: 1
# Found label directory: Eugene_Teslovic
#   Images found in Eugene_Teslovic: 1
# Found label directory: Larry_Bowa
#   Images found in Larry_Bowa: 2
# Found label directory: Dave_McNally
#   Images found in Dave_McNally: 1
# Found label directory: Sam_Mendes
#   Images found in Sam_Mendes: 2
# Found label directory: Alejandro_Fernandez
#   Images found in Alejandro_Fernandez: 1
# Found label directory: Dewayne_White
#   Images found in Dewayne_White: 1
# Found label directory: John_Lithgow
#   Images found in John_Lithgow: 1
# Found label directory: Howard_Stringer
#   Images found in Howard_Stringer: 1
# Found label directory: Ty_Votaw
#   Images found in Ty_Votaw: 1
# Found label directory: Earl_Fritts
#   Images found in Earl_Fritts: 1
# Found label directory: Rick_Caruso
#   Images found in Rick_Caruso: 1
# Found label directory: Tom_Vilsack
#   Images found in Tom_Vilsack: 1
# Found label directory: Rick_Wagoner
#   Images found in Rick_Wagoner: 2
# Found label directory: Peter_Caruana
#   Images found in Peter_Caruana: 1
# Found label directory: Muammar_Gaddafi
#   Images found in Muammar_Gaddafi: 2
# Found label directory: Li_Ruihuan
#   Images found in Li_Ruihuan: 1
# Found label directory: Stefan_Koubek
#   Images found in Stefan_Koubek: 1
# Found label directory: Paul_Kagame
#   Images found in Paul_Kagame: 2
# Found label directory: Renato_Soru
#   Images found in Renato_Soru: 1
# Found label directory: Isidro_Pastor
#   Images found in Isidro_Pastor: 1
# Found label directory: Sadie_Frost
#   Images found in Sadie_Frost: 3
# Found label directory: Catherine_Bell
#   Images found in Catherine_Bell: 1
# Found label directory: Emyr_Jones_Parry
#   Images found in Emyr_Jones_Parry: 1
# Found label directory: Omar_Khan_Sharif
#   Images found in Omar_Khan_Sharif: 1
# Found label directory: Jennifer_Granholm
#   Images found in Jennifer_Granholm: 1
# Found label directory: Lorne_Michaels
#   Images found in Lorne_Michaels: 1
# Found label directory: Donatella_Versace
#   Images found in Donatella_Versace: 3
# Found label directory: Fredric_Seaman
#   Images found in Fredric_Seaman: 1
# Found label directory: Darvis_Patton
#   Images found in Darvis_Patton: 1
# Found label directory: Nancy_Humbert
#   Images found in Nancy_Humbert: 1
# Found label directory: Robin_Tunney
#   Images found in Robin_Tunney: 1
# Found label directory: Svetislav_Pesic
#   Images found in Svetislav_Pesic: 1
# Found label directory: Gerrit_Zalm
#   Images found in Gerrit_Zalm: 1
# Found label directory: Philip_Murtaugh
#   Images found in Philip_Murtaugh: 1
# Found label directory: Dianne_Reeves
#   Images found in Dianne_Reeves: 1
# Found label directory: Lela_Rochon
#   Images found in Lela_Rochon: 1
# Found label directory: Eli_Rosenbaum
#   Images found in Eli_Rosenbaum: 1
# Found label directory: Ronald_Reagan
#   Images found in Ronald_Reagan: 3
# Found label directory: Mike_Matheny
#   Images found in Mike_Matheny: 1
# Found label directory: Roy_Williams
#   Images found in Roy_Williams: 4
# Found label directory: Beth_Jones
#   Images found in Beth_Jones: 2
# Found label directory: Leander_Paes
#   Images found in Leander_Paes: 2
# Found label directory: Al_Pacino
#   Images found in Al_Pacino: 3
# Found label directory: Cari_Davis
#   Images found in Cari_Davis: 1
# Found label directory: Barry_Hinson
#   Images found in Barry_Hinson: 1
# Found label directory: Bryan_Chui
#   Images found in Bryan_Chui: 1
# Found label directory: Mathias_Reichhold
#   Images found in Mathias_Reichhold: 3
# Found label directory: David_Leahy
#   Images found in David_Leahy: 2
# Found label directory: Sadam_Hassan
#   Images found in Sadam_Hassan: 1
# Found label directory: Stanley_McChrystal
#   Images found in Stanley_McChrystal: 3
# Found label directory: Charlie_Zaa
#   Images found in Charlie_Zaa: 2
# Found label directory: Emelie_Loit
#   Images found in Emelie_Loit: 1
# Found label directory: Adam_Sandler
#   Images found in Adam_Sandler: 4
# Found label directory: Donald_Fehr
#   Images found in Donald_Fehr: 4
# Found label directory: Antanas_Valionis
#   Images found in Antanas_Valionis: 1
# Found label directory: Kurt_Suzuki
#   Images found in Kurt_Suzuki: 1
# Found label directory: Kelvin_Sampson
#   Images found in Kelvin_Sampson: 3
# Found label directory: Alexander_Payne
#   Images found in Alexander_Payne: 1
# Found label directory: Vincent_Gallo
#   Images found in Vincent_Gallo: 3
# Found label directory: Zavad_Zarif
#   Images found in Zavad_Zarif: 1
# Found label directory: Ed_Rosenthal
#   Images found in Ed_Rosenthal: 3
# Found label directory: Russell_Coutts
#   Images found in Russell_Coutts: 2
# Found label directory: Joseph_Fiennes
#   Images found in Joseph_Fiennes: 1
# Found label directory: Andy_North
#   Images found in Andy_North: 1
# Found label directory: Alexandre_Vinokourov
#   Images found in Alexandre_Vinokourov: 1
# Found label directory: George_Galloway
#   Images found in George_Galloway: 4
# Found label directory: Jan_Ullrich
#   Images found in Jan_Ullrich: 6
# Found label directory: Franklin_Brown
#   Images found in Franklin_Brown: 1
# Found label directory: Michel_Therrien
#   Images found in Michel_Therrien: 2
# Found label directory: Silvia_Farina_Elia
#   Images found in Silvia_Farina_Elia: 3
# Found label directory: James_Franco
#   Images found in James_Franco: 2
# Found label directory: David_Donohue
#   Images found in David_Donohue: 1
# Found label directory: Richard_Carl
#   Images found in Richard_Carl: 1
# Found label directory: Mikhail_Shvydkoi
#   Images found in Mikhail_Shvydkoi: 1
# Found label directory: Alejandro_Gonzalez_Inarritu
#   Images found in Alejandro_Gonzalez_Inarritu: 1
# Found label directory: Robert_Torricelli
#   Images found in Robert_Torricelli: 3
# Found label directory: Allan_Houston
#   Images found in Allan_Houston: 1
# Found label directory: John_Swofford
#   Images found in John_Swofford: 3
# Found label directory: Debra_Messing
#   Images found in Debra_Messing: 3
# Found label directory: Kevin_Borseth
#   Images found in Kevin_Borseth: 1
# Found label directory: Roland_Koch
#   Images found in Roland_Koch: 1
# Found label directory: Mike_Krzyzewski
#   Images found in Mike_Krzyzewski: 6
# Found label directory: Marvan_Atapattu
#   Images found in Marvan_Atapattu: 1
# Found label directory: Dieter_Holzer
#   Images found in Dieter_Holzer: 1
# Found label directory: Peggy_McGuinness
#   Images found in Peggy_McGuinness: 1
# Found label directory: Brian_Mulroney
#   Images found in Brian_Mulroney: 2
# Found label directory: Robert_Bonner
#   Images found in Robert_Bonner: 3
# Found label directory: Cindy_Taylor
#   Images found in Cindy_Taylor: 1
# Found label directory: Bustam_A_Zedan_Aljanabi
#   Images found in Bustam_A_Zedan_Aljanabi: 1
# Found label directory: Cho_Myung-kyun
#   Images found in Cho_Myung-kyun: 1
# Found label directory: Shawn_Kemp
#   Images found in Shawn_Kemp: 1
# Found label directory: Mauro_Viza
#   Images found in Mauro_Viza: 1
# Found label directory: Xavier_Malisse
#   Images found in Xavier_Malisse: 5
# Found label directory: Miranda_Gaddis
#   Images found in Miranda_Gaddis: 1
# Found label directory: Charlotte_Church
#   Images found in Charlotte_Church: 1
# Found label directory: Al_Leiter
#   Images found in Al_Leiter: 1
# Found label directory: Noel_Forgeard
#   Images found in Noel_Forgeard: 1
# Found label directory: William_Cocksedge
#   Images found in William_Cocksedge: 1
# Found label directory: Randall_Terry
#   Images found in Randall_Terry: 1
# Found label directory: Lou_Lang
#   Images found in Lou_Lang: 1
# Found label directory: Christopher_Matero
#   Images found in Christopher_Matero: 1
# Found label directory: Leandrinho_Barbosa
#   Images found in Leandrinho_Barbosa: 1
# Found label directory: Roger_Daltrey
#   Images found in Roger_Daltrey: 1
# Found label directory: Moon-So-ri
#   Images found in Moon-So-ri: 1
# Found label directory: Adam_Scott
#   Images found in Adam_Scott: 2
# Found label directory: Jeffrey_Pfeffer
#   Images found in Jeffrey_Pfeffer: 1
# Found label directory: Cori_Enghusen
#   Images found in Cori_Enghusen: 1
# Found label directory: Juan_Carlos_Ferrero
#   Images found in Juan_Carlos_Ferrero: 28
# Found label directory: Malak_Habbak
#   Images found in Malak_Habbak: 1
# Found label directory: Joseph_Estrada
#   Images found in Joseph_Estrada: 4
# Found label directory: Brian_Cowen
#   Images found in Brian_Cowen: 2
# Found label directory: Li_Ka-shing
#   Images found in Li_Ka-shing: 1
# Found label directory: Carolina_Moraes
#   Images found in Carolina_Moraes: 2
# Found label directory: Andy_Griffith
#   Images found in Andy_Griffith: 1
# Found label directory: Norodom_Chakrapong
#   Images found in Norodom_Chakrapong: 1
# Found label directory: Radovan_Karadzic
#   Images found in Radovan_Karadzic: 1
# Found label directory: Wolfgang_Schneiderhan
#   Images found in Wolfgang_Schneiderhan: 1
# Found label directory: Lee_Nam-shin
#   Images found in Lee_Nam-shin: 1
# Found label directory: Taufik_Kiemas
#   Images found in Taufik_Kiemas: 1
# Found label directory: Hu_Maoyuan
#   Images found in Hu_Maoyuan: 1
# Found label directory: Demi_Moore
#   Images found in Demi_Moore: 4
# Found label directory: John_Ferguson
#   Images found in John_Ferguson: 1
# Found label directory: Jose_Dirceu
#   Images found in Jose_Dirceu: 2
# Found label directory: Chris_Bell
#   Images found in Chris_Bell: 2
# Found label directory: Tyler_Hamilton
#   Images found in Tyler_Hamilton: 2
# Found label directory: Danny_Morgan
#   Images found in Danny_Morgan: 1
# Found label directory: Roger_Corbett
#   Images found in Roger_Corbett: 1
# Found label directory: Rick_Dinse
#   Images found in Rick_Dinse: 3
# Found label directory: Mitchell_Garabedian
#   Images found in Mitchell_Garabedian: 1
# Found label directory: James_Ballenger
#   Images found in James_Ballenger: 1
# Found label directory: Narendra_Modi
#   Images found in Narendra_Modi: 1
# Found label directory: Bruna_Colosio
#   Images found in Bruna_Colosio: 1
# Found label directory: Paul_Henderson
#   Images found in Paul_Henderson: 1
# Found label directory: Bo_Ryan
#   Images found in Bo_Ryan: 2
# Found label directory: Mike_Babcock
#   Images found in Mike_Babcock: 2
# Found label directory: Stephen_Daldry
#   Images found in Stephen_Daldry: 2
# Found label directory: Zach_Safrin
#   Images found in Zach_Safrin: 1
# Found label directory: Richard_Jefferson
#   Images found in Richard_Jefferson: 1
# Found label directory: Romano_Prodi
#   Images found in Romano_Prodi: 7
# Found label directory: Maria_Luisa_Mendonca
#   Images found in Maria_Luisa_Mendonca: 2
# Found label directory: Eric_Benet
#   Images found in Eric_Benet: 1
# Found label directory: Rio_Ferdinand
#   Images found in Rio_Ferdinand: 2
# Found label directory: Alejandro_Avila
#   Images found in Alejandro_Avila: 3
# Found label directory: Hana_Urushima
#   Images found in Hana_Urushima: 1
# Found label directory: Greg_Rusedski
#   Images found in Greg_Rusedski: 4
# Found label directory: Tara_Dawn_Christensen
#   Images found in Tara_Dawn_Christensen: 1
# Found label directory: Pedro_Martinez
#   Images found in Pedro_Martinez: 1
# Found label directory: Hilary_Duff
#   Images found in Hilary_Duff: 3
# Found label directory: Jorge_Batlle
#   Images found in Jorge_Batlle: 3
# Found label directory: Lonnie_Donegan
#   Images found in Lonnie_Donegan: 1
# Found label directory: Carlos_Ruiz
#   Images found in Carlos_Ruiz: 3
# Found label directory: Princess_Stephanie
#   Images found in Princess_Stephanie: 1
# Found label directory: Heidi_Klum
#   Images found in Heidi_Klum: 5
# Found label directory: Joe_Torre
#   Images found in Joe_Torre: 4
# Found label directory: Billy_Andrade
#   Images found in Billy_Andrade: 1
# Found label directory: Tracy_McGrady
#   Images found in Tracy_McGrady: 2
# Found label directory: Michelle_Kwan
#   Images found in Michelle_Kwan: 8
# Found label directory: Todd_Parrott
#   Images found in Todd_Parrott: 1
# Found label directory: Amy_Pascal
#   Images found in Amy_Pascal: 1
# Found label directory: Jim_Jeffords
#   Images found in Jim_Jeffords: 1
# Found label directory: Jim_Hardin
#   Images found in Jim_Hardin: 1
# Found label directory: Thomas_Watjen
#   Images found in Thomas_Watjen: 1
# Found label directory: Joshua_Harapko
#   Images found in Joshua_Harapko: 1
# Found label directory: Jim_Tressel
#   Images found in Jim_Tressel: 4
# Found label directory: Thomas_Cloyd
#   Images found in Thomas_Cloyd: 1
# Found label directory: Tomas_Malik
#   Images found in Tomas_Malik: 1
# Found label directory: Danny_Ainge
#   Images found in Danny_Ainge: 1
# Found label directory: Hassan_Nasrallah
#   Images found in Hassan_Nasrallah: 2
# Found label directory: John_Williams
#   Images found in John_Williams: 1
# Found label directory: Jason_Vale
#   Images found in Jason_Vale: 1
# Found label directory: Christian_Gimenez
#   Images found in Christian_Gimenez: 1
# Found label directory: Joaquim_Rodriguez
#   Images found in Joaquim_Rodriguez: 1
# Found label directory: Janet_Crawford
#   Images found in Janet_Crawford: 1
# Found label directory: Shireen_Amir_Begum
#   Images found in Shireen_Amir_Begum: 1
# Found label directory: Chris_Byrd
#   Images found in Chris_Byrd: 2
# Found label directory: Gina_Lollobrigida
#   Images found in Gina_Lollobrigida: 1
# Found label directory: Shafal_Mosed
#   Images found in Shafal_Mosed: 1
# Found label directory: Michael_Clarke_Duncan
#   Images found in Michael_Clarke_Duncan: 1
# Found label directory: Teri_Garr
#   Images found in Teri_Garr: 1
# Found label directory: Barbara_Bodine
#   Images found in Barbara_Bodine: 1
# Found label directory: Steve_Stirling
#   Images found in Steve_Stirling: 1
# Found label directory: Hideki_Matsui
#   Images found in Hideki_Matsui: 2
# Found label directory: Connie_Chung
#   Images found in Connie_Chung: 1
# Found label directory: Joe_Lieberman
#   Images found in Joe_Lieberman: 13
# Found label directory: Damon_Dash
#   Images found in Damon_Dash: 1
# Found label directory: Britney_Spears
#   Images found in Britney_Spears: 14
# Found label directory: Benjamin_McKenzie
#   Images found in Benjamin_McKenzie: 1
# Found label directory: Jim_Beattie
#   Images found in Jim_Beattie: 1
# Found label directory: Bob_Stoops
#   Images found in Bob_Stoops: 7
# Found label directory: Stephane_Rousseau
#   Images found in Stephane_Rousseau: 1
# Found label directory: Derrick_Rodgers
#   Images found in Derrick_Rodgers: 1
# Found label directory: Alejandro_Toledo
#   Images found in Alejandro_Toledo: 39
# Found label directory: Mark_Gangloff
#   Images found in Mark_Gangloff: 1
# Found label directory: Tara_Kirk
#   Images found in Tara_Kirk: 1
# Found label directory: Juan_Pablo_Montoya
#   Images found in Juan_Pablo_Montoya: 8
# Found label directory: Martin_Brodeur
#   Images found in Martin_Brodeur: 2
# Found label directory: Mel_Gibson
#   Images found in Mel_Gibson: 2
# Found label directory: Robby_Ginepri
#   Images found in Robby_Ginepri: 2
# Found label directory: Han_Sung_Joo
#   Images found in Han_Sung_Joo: 1
# Found label directory: Taylyn_Solomon
#   Images found in Taylyn_Solomon: 1
# Found label directory: Rolandas_Paksas
#   Images found in Rolandas_Paksas: 2
# Found label directory: Mike_Sherman
#   Images found in Mike_Sherman: 1
# Found label directory: Maurice_Strong
#   Images found in Maurice_Strong: 1
# Found label directory: Roger_Moore
#   Images found in Roger_Moore: 5
# Found label directory: Kellie_Greene
#   Images found in Kellie_Greene: 1
# Found label directory: Caroline_Dhavernas
#   Images found in Caroline_Dhavernas: 1
# Found label directory: Earl_Campbell
#   Images found in Earl_Campbell: 1
# Found label directory: Andreas_Vinciguerra
#   Images found in Andreas_Vinciguerra: 1
# Found label directory: Camille_Colvin
#   Images found in Camille_Colvin: 1
# Found label directory: Catherine_Ndereba
#   Images found in Catherine_Ndereba: 1
# Found label directory: Oleg_Romantsev
#   Images found in Oleg_Romantsev: 1
# Found label directory: Alvaro_Noboa
#   Images found in Alvaro_Noboa: 3
# Found label directory: Jennifer_Furminger
#   Images found in Jennifer_Furminger: 1
# Found label directory: Roy_Jones_Jr
#   Images found in Roy_Jones_Jr: 2
# Found label directory: Ted_Washington
#   Images found in Ted_Washington: 1
# Found label directory: Jacques_Chirac
#   Images found in Jacques_Chirac: 52
# Found label directory: Anna_Kournikova
#   Images found in Anna_Kournikova: 12
# Found label directory: Juan_Ignacio_Chela
#   Images found in Juan_Ignacio_Chela: 3
# Found label directory: Pete_Carroll
#   Images found in Pete_Carroll: 3
# Found label directory: Andrew_Shutley
#   Images found in Andrew_Shutley: 1
# Found label directory: Stellan_Skarsgard
#   Images found in Stellan_Skarsgard: 2
# Found label directory: Dai_Chul_Chyung
#   Images found in Dai_Chul_Chyung: 1
# Found label directory: Javier_Camara
#   Images found in Javier_Camara: 1
# Found label directory: Mike_Weir
#   Images found in Mike_Weir: 11
# Found label directory: Miguel_Aldana_Ibarra
#   Images found in Miguel_Aldana_Ibarra: 1
# Found label directory: Chuck_Hagel
#   Images found in Chuck_Hagel: 1
# Found label directory: Juliette_Binoche
#   Images found in Juliette_Binoche: 1
# Found label directory: Damon_van_Dam
#   Images found in Damon_van_Dam: 2
# Found label directory: Mariana_Pollack
#   Images found in Mariana_Pollack: 3
# Found label directory: Elena_Tihomirova
#   Images found in Elena_Tihomirova: 1
# Found label directory: Ron_Howard
#   Images found in Ron_Howard: 2
# Found label directory: Viola_Davis
#   Images found in Viola_Davis: 1
# Found label directory: Dale_Earnhardt_Jr
#   Images found in Dale_Earnhardt_Jr: 4
# Found label directory: Morris_Dees
#   Images found in Morris_Dees: 1
# Found label directory: Patti_Balgojevich
#   Images found in Patti_Balgojevich: 1
# Found label directory: Rina_Lazo
#   Images found in Rina_Lazo: 1
# Found label directory: Colleen_Donovan
#   Images found in Colleen_Donovan: 1
# Found label directory: Brandon_Boyd
#   Images found in Brandon_Boyd: 1
# Found label directory: Simon_Cowell
#   Images found in Simon_Cowell: 2
# Found label directory: Gilberto_Rodriguez_Orejuela
#   Images found in Gilberto_Rodriguez_Orejuela: 4
# Found label directory: Ruben_Sierra
#   Images found in Ruben_Sierra: 1
# Found label directory: Kyle_McLaren
#   Images found in Kyle_McLaren: 1
# Found label directory: Kwon_Yang-sook
#   Images found in Kwon_Yang-sook: 3
# Found label directory: Harvey_Fierstein
#   Images found in Harvey_Fierstein: 1
# Found label directory: Ashlea_Talbot
#   Images found in Ashlea_Talbot: 1
# Found label directory: Ben_Betts
#   Images found in Ben_Betts: 1
# Found label directory: Gideon_Yago
#   Images found in Gideon_Yago: 1
# Found label directory: Lord_Hutton
#   Images found in Lord_Hutton: 2
# Found label directory: Elgin_Baylor
#   Images found in Elgin_Baylor: 1
# Found label directory: Sara_Silverman
#   Images found in Sara_Silverman: 1
# Found label directory: Morgan_Fairchild
#   Images found in Morgan_Fairchild: 1
# Found label directory: Karen_Pereiras
#   Images found in Karen_Pereiras: 1
# Found label directory: Alicia_Silverstone
#   Images found in Alicia_Silverstone: 2
# Found label directory: Aretha_Franklin
#   Images found in Aretha_Franklin: 1
# Found label directory: Peter_Bacanovic
#   Images found in Peter_Bacanovic: 2
# Found label directory: Guillaume_Cannet
#   Images found in Guillaume_Cannet: 1
# Found label directory: Patty_Duke
#   Images found in Patty_Duke: 1
# Found label directory: Paul_Newman
#   Images found in Paul_Newman: 1
# Found label directory: James_Hoffa
#   Images found in James_Hoffa: 1
# Found label directory: LeAnn_Rimes
#   Images found in LeAnn_Rimes: 2
# Found label directory: Muhammad_Ali
#   Images found in Muhammad_Ali: 10
# Found label directory: Jason_Mewes
#   Images found in Jason_Mewes: 1
# Found label directory: Andy_Hebb
#   Images found in Andy_Hebb: 2
# Found label directory: Charles_Holzner
#   Images found in Charles_Holzner: 1
# Found label directory: Anastasia_Myskina
#   Images found in Anastasia_Myskina: 3
# Found label directory: Vagit_Alekperov
#   Images found in Vagit_Alekperov: 1
# Found label directory: David_Siegel
#   Images found in David_Siegel: 1
# Found label directory: David_Caraway
#   Images found in David_Caraway: 2
# Found label directory: Don_Hewitt
#   Images found in Don_Hewitt: 1
# Found label directory: Esther_Macklin
#   Images found in Esther_Macklin: 1
# Found label directory: Christopher_Russell
#   Images found in Christopher_Russell: 1
# Found label directory: Tim_Conway
#   Images found in Tim_Conway: 3
# Found label directory: Skip_Prosser
#   Images found in Skip_Prosser: 1
# Found label directory: Brian_Heidik
#   Images found in Brian_Heidik: 2
# Found label directory: Sandra_Shamas
#   Images found in Sandra_Shamas: 1
# Found label directory: Corinne_Coman
#   Images found in Corinne_Coman: 2
# Found label directory: Jerry_Tarkanian
#   Images found in Jerry_Tarkanian: 1
# Found label directory: Sylvia_Plachy
#   Images found in Sylvia_Plachy: 1
# Found label directory: Jean-Claude_Van_Damme
#   Images found in Jean-Claude_Van_Damme: 1
# Found label directory: Kim_Ryong-sung
#   Images found in Kim_Ryong-sung: 11
# Found label directory: Hun_Sen
#   Images found in Hun_Sen: 4
# Found label directory: Nida_Blanca
#   Images found in Nida_Blanca: 1
# Found label directory: Helio_Rubens_Garcia
#   Images found in Helio_Rubens_Garcia: 1
# Found label directory: Pierre_Lacroix
#   Images found in Pierre_Lacroix: 1
# Found label directory: Michel_Kratochvil
#   Images found in Michel_Kratochvil: 1
# Found label directory: Andrew_Fastow
#   Images found in Andrew_Fastow: 1
# Found label directory: Hal_Gehman
#   Images found in Hal_Gehman: 5
# Found label directory: Jimmy_Carter
#   Images found in Jimmy_Carter: 9
# Found label directory: Elaine_Chao
#   Images found in Elaine_Chao: 1
# Found label directory: Barbara_Boxer
#   Images found in Barbara_Boxer: 1
# Found label directory: Karin_Viard
#   Images found in Karin_Viard: 1
# Found label directory: Sinead_OConnor
#   Images found in Sinead_OConnor: 1
# Found label directory: Kim_Cattrall
#   Images found in Kim_Cattrall: 1
# Found label directory: Matt_Braker
#   Images found in Matt_Braker: 1
# Found label directory: Diana_Taylor
#   Images found in Diana_Taylor: 1
# Found label directory: Luiz_Inacio_Lula_da_Silva
#   Images found in Luiz_Inacio_Lula_da_Silva: 48
# Found label directory: Donald_Pettit
#   Images found in Donald_Pettit: 3
# Found label directory: Michael_Jasny
#   Images found in Michael_Jasny: 1
# Found label directory: Gustavo_Cisneros
#   Images found in Gustavo_Cisneros: 1
# Warning: pairs_08.txt is not a directory
# Found label directory: Supachai_Panitchpakdi
#   Images found in Supachai_Panitchpakdi: 1
# Found label directory: Chris_Swecker
#   Images found in Chris_Swecker: 1
# Found label directory: Javier_Bardem
#   Images found in Javier_Bardem: 1
# Found label directory: Saburo_Kawabuchi
#   Images found in Saburo_Kawabuchi: 2
# Found label directory: Nestor_Gonzalez
#   Images found in Nestor_Gonzalez: 1
# Found label directory: E_Clay_Shaw
#   Images found in E_Clay_Shaw: 1
# Found label directory: Vanessa_Williams
#   Images found in Vanessa_Williams: 3
# Found label directory: Gonzalo_Barrientos
#   Images found in Gonzalo_Barrientos: 1
# Found label directory: Michael_Taylor
#   Images found in Michael_Taylor: 1
# Found label directory: Fernando_Leon_de_Aranoa
#   Images found in Fernando_Leon_de_Aranoa: 1
# Found label directory: Brett_Hawke
#   Images found in Brett_Hawke: 1
# Found label directory: Peter_Ahearn
#   Images found in Peter_Ahearn: 1
# Found label directory: Arianna_Huffington
#   Images found in Arianna_Huffington: 4
# Found label directory: Fazal-ur-Rehman
#   Images found in Fazal-ur-Rehman: 1
# Found label directory: Paul_William_Hurley
#   Images found in Paul_William_Hurley: 2
# Found label directory: Gerard_Butler
#   Images found in Gerard_Butler: 1
# Found label directory: Maria_Wetterstrand
#   Images found in Maria_Wetterstrand: 1
# Found label directory: Soon_Yi
#   Images found in Soon_Yi: 1
# Found label directory: Francisco_Santos
#   Images found in Francisco_Santos: 1
# Found label directory: Sharon_Osbourne
#   Images found in Sharon_Osbourne: 3
# Found label directory: Alfonso_Soriano
#   Images found in Alfonso_Soriano: 1
# Found label directory: Bryan_Murray
#   Images found in Bryan_Murray: 1
# Found label directory: Job_Cohen
#   Images found in Job_Cohen: 2
# Found label directory: Marina_Canetti
#   Images found in Marina_Canetti: 1
# Found label directory: Elizabeth_Pena
#   Images found in Elizabeth_Pena: 1
# Found label directory: Rudy_Tomjanovich
#   Images found in Rudy_Tomjanovich: 1
# Found label directory: Hal_Sellers
#   Images found in Hal_Sellers: 1
# Found label directory: Michael_Denzel
#   Images found in Michael_Denzel: 1
# Found label directory: AJ_Lamas
#   Images found in AJ_Lamas: 1
# Found label directory: Felix_Mantilla
#   Images found in Felix_Mantilla: 2
# Found label directory: Joe_Carnahan
#   Images found in Joe_Carnahan: 1
# Found label directory: Leni_Bjorklund
#   Images found in Leni_Bjorklund: 1
# Found label directory: Howard_Smith
#   Images found in Howard_Smith: 2
# Found label directory: David_Przybyszewski
#   Images found in David_Przybyszewski: 1
# Found label directory: Faisal_Iqbal
#   Images found in Faisal_Iqbal: 1
# Found label directory: David_Millar
#   Images found in David_Millar: 1
# Found label directory: Jean_Brumley
#   Images found in Jean_Brumley: 2
# Found label directory: Wanda_Ilene_Barzee
#   Images found in Wanda_Ilene_Barzee: 1
# Found label directory: Mukhtar_Alytnbayev
#   Images found in Mukhtar_Alytnbayev: 1
# Found label directory: Carlos_Ghosn
#   Images found in Carlos_Ghosn: 2
# Found label directory: Hong_Myung
#   Images found in Hong_Myung: 1
# Found label directory: Christy_Ferer
#   Images found in Christy_Ferer: 1
# Found label directory: Wanda_de_la_Jesus
#   Images found in Wanda_de_la_Jesus: 1
# Found label directory: Amy_Yasbeck
#   Images found in Amy_Yasbeck: 1
# Found label directory: Shane_Hmiel
#   Images found in Shane_Hmiel: 1
# Found label directory: Jorge_Quiroga
#   Images found in Jorge_Quiroga: 1
# Found label directory: Estelle_Morris
#   Images found in Estelle_Morris: 1
# Found label directory: Tonino_Guerra
#   Images found in Tonino_Guerra: 1
# Found label directory: Patty_Sheehan
#   Images found in Patty_Sheehan: 1
# Found label directory: Ken_Kutaragi
#   Images found in Ken_Kutaragi: 1
# Found label directory: Doug_Duncan
#   Images found in Doug_Duncan: 2
# Found label directory: George_Murphy
#   Images found in George_Murphy: 1
# Found label directory: Pedro_Mahecha
#   Images found in Pedro_Mahecha: 1
# Found label directory: James_Coviello
#   Images found in James_Coviello: 1
# Found label directory: Gregorio_Rosal
#   Images found in Gregorio_Rosal: 1
# Found label directory: Amelie_Mauresmo
#   Images found in Amelie_Mauresmo: 21
# Found label directory: Claudio_Abbado
#   Images found in Claudio_Abbado: 1
# Found label directory: Ellen_MacArthur
#   Images found in Ellen_MacArthur: 1
# Found label directory: Martin_Landau
#   Images found in Martin_Landau: 1
# Found label directory: Jamling_Norgay
#   Images found in Jamling_Norgay: 2
# Found label directory: Bob_Hope
#   Images found in Bob_Hope: 8
# Found label directory: Thomas_Weston
#   Images found in Thomas_Weston: 1
# Found label directory: John_Warner
#   Images found in John_Warner: 4
# Found label directory: Jim_Ryan
#   Images found in Jim_Ryan: 1
# Warning: pairs_07.txt is not a directory
# Found label directory: James_Hughes
#   Images found in James_Hughes: 1
# Found label directory: Buck_Rodgers
#   Images found in Buck_Rodgers: 1
# Found label directory: Alexandra_Vodjanikova
#   Images found in Alexandra_Vodjanikova: 2
# Found label directory: Kalid_Kaid
#   Images found in Kalid_Kaid: 1
# Found label directory: Vladimir_Voltchkov
#   Images found in Vladimir_Voltchkov: 2
# Found label directory: John_Travolta
#   Images found in John_Travolta: 7
# Found label directory: Steve_Largent
#   Images found in Steve_Largent: 1
# Found label directory: James_Kopp
#   Images found in James_Kopp: 4
# Found label directory: Robbie_Williams
#   Images found in Robbie_Williams: 3
# Found label directory: Guillermo_Ortiz
#   Images found in Guillermo_Ortiz: 2
# Found label directory: Helene_Eksterowicz
#   Images found in Helene_Eksterowicz: 1
# Found label directory: Margaret_Caruso
#   Images found in Margaret_Caruso: 1
# Found label directory: Patricia_Clarkson
#   Images found in Patricia_Clarkson: 4
# Found label directory: Roman_Polanski
#   Images found in Roman_Polanski: 6
# Found label directory: Miles_Stewart
#   Images found in Miles_Stewart: 1
# Found label directory: Albert_Costa
#   Images found in Albert_Costa: 6
# Found label directory: Gregory_Geoffroy
#   Images found in Gregory_Geoffroy: 2
# Found label directory: Bill_Belichick
#   Images found in Bill_Belichick: 2
# Found label directory: Peter_Greenaway
#   Images found in Peter_Greenaway: 2
# Found label directory: Lana_Clarkson
#   Images found in Lana_Clarkson: 2
# Found label directory: Dominik_Hrbaty
#   Images found in Dominik_Hrbaty: 1
# Found label directory: Charlie_Coles
#   Images found in Charlie_Coles: 1
# Found label directory: Zhang_Ziyi
#   Images found in Zhang_Ziyi: 4
# Found label directory: Chang_Dae-whan
#   Images found in Chang_Dae-whan: 2
# Found label directory: Bill_Nelson
#   Images found in Bill_Nelson: 2
# Found label directory: Daryl_Hannah
#   Images found in Daryl_Hannah: 2
# Found label directory: Perry_Farrell
#   Images found in Perry_Farrell: 1
# Found label directory: Hosni_Mubarak
#   Images found in Hosni_Mubarak: 9
# Found label directory: Poala_Suarez
#   Images found in Poala_Suarez: 1
# Found label directory: Paul_Shanley
#   Images found in Paul_Shanley: 3
# Found label directory: Sarah_Wynter
#   Images found in Sarah_Wynter: 1
# Found label directory: Jose_Woldenberg
#   Images found in Jose_Woldenberg: 1
# Found label directory: George_Blaney
#   Images found in George_Blaney: 1
# Found label directory: Mark_Heller
#   Images found in Mark_Heller: 2
# Found label directory: Yoon_Won-Sik
#   Images found in Yoon_Won-Sik: 1
# Found label directory: Fruit_Chan
#   Images found in Fruit_Chan: 1
# Found label directory: Daniele_Nardello
#   Images found in Daniele_Nardello: 1
# Found label directory: Sananda_Maitreya
#   Images found in Sananda_Maitreya: 1
# Found label directory: Wendy_Kennedy
#   Images found in Wendy_Kennedy: 1
# Found label directory: Saddam_Hussein
#   Images found in Saddam_Hussein: 23
# Found label directory: Carlos_Menem
#   Images found in Carlos_Menem: 21
# Found label directory: Yao_Ming
#   Images found in Yao_Ming: 8
# Found label directory: Maha_Habib
#   Images found in Maha_Habib: 1
# Found label directory: Roy_Moore
#   Images found in Roy_Moore: 6
# Found label directory: Raquel_Welch
#   Images found in Raquel_Welch: 2
# Found label directory: Paul_Ebert
#   Images found in Paul_Ebert: 1
# Found label directory: Keith_Snyder
#   Images found in Keith_Snyder: 1
# Found label directory: Roger_King
#   Images found in Roger_King: 1
# Found label directory: Damon_Stoudamire
#   Images found in Damon_Stoudamire: 1
# Found label directory: Martie_Maguire
#   Images found in Martie_Maguire: 1
# Found label directory: Shia_LaBeouf
#   Images found in Shia_LaBeouf: 2
# Found label directory: Mikulas_Dzurinda
#   Images found in Mikulas_Dzurinda: 2
# Found label directory: Wallace_Capel
#   Images found in Wallace_Capel: 1
# Found label directory: Steve_Peace
#   Images found in Steve_Peace: 1
# Found label directory: Ismail_Merchant
#   Images found in Ismail_Merchant: 2
# Found label directory: Dean_Sheremet
#   Images found in Dean_Sheremet: 1
# Found label directory: Thomas_Van_Essen
#   Images found in Thomas_Van_Essen: 1
# Found label directory: Sonia_Gandhi
#   Images found in Sonia_Gandhi: 4
# Found label directory: Lokendra_Bahadur_Chand
#   Images found in Lokendra_Bahadur_Chand: 1
# Found label directory: Kirk_Douglas
#   Images found in Kirk_Douglas: 1
# Found label directory: Jessica_Capshaw
#   Images found in Jessica_Capshaw: 1
# Found label directory: Mickey_Gilley
#   Images found in Mickey_Gilley: 1
# Found label directory: David_Brown
#   Images found in David_Brown: 1
# Found label directory: Olivier_Boulay
#   Images found in Olivier_Boulay: 1
# Found label directory: Romario_Farias
#   Images found in Romario_Farias: 1
# Found label directory: Anita_DeFrantz
#   Images found in Anita_DeFrantz: 1
# Found label directory: Raoul_Ruiz
#   Images found in Raoul_Ruiz: 4
# Found label directory: Iain_Duncan_Smith
#   Images found in Iain_Duncan_Smith: 4
# Found label directory: Martha_Beatriz_Roque
#   Images found in Martha_Beatriz_Roque: 2
# Found label directory: Manfred_Reyes_Villa
#   Images found in Manfred_Reyes_Villa: 1
# Found label directory: Aitor_Gonzalez
#   Images found in Aitor_Gonzalez: 2
# Found label directory: Jorge_Rodolfo_Canicoba_Corral
#   Images found in Jorge_Rodolfo_Canicoba_Corral: 2
# Found label directory: Adoor_Gopalakarishnan
#   Images found in Adoor_Gopalakarishnan: 1
# Found label directory: Sterling_Hitchcock
#   Images found in Sterling_Hitchcock: 1
# Found label directory: Michael_Chiklis
#   Images found in Michael_Chiklis: 5
# Found label directory: Mike_Tyson
#   Images found in Mike_Tyson: 4
# Found label directory: Jim_Doyle
#   Images found in Jim_Doyle: 1
# Found label directory: David_Dodge
#   Images found in David_Dodge: 2
# Found label directory: Hanan_Ashrawi
#   Images found in Hanan_Ashrawi: 2
# Found label directory: Marcos_Daniel_Jimenez
#   Images found in Marcos_Daniel_Jimenez: 1
# Found label directory: Calvin_Joseph_Coleman
#   Images found in Calvin_Joseph_Coleman: 1
# Found label directory: Eglis_Yaima_Cruz
#   Images found in Eglis_Yaima_Cruz: 1
# Found label directory: Keith_Fotta
#   Images found in Keith_Fotta: 1
# Found label directory: Hanns_Schumacher
#   Images found in Hanns_Schumacher: 1
# Found label directory: Brian_Williams
#   Images found in Brian_Williams: 1
# Found label directory: Debra_Rose
#   Images found in Debra_Rose: 1
# Found label directory: Chick_Hearn
#   Images found in Chick_Hearn: 3
# Found label directory: Dean_Barker
#   Images found in Dean_Barker: 1
# Found label directory: Arie_Haan
#   Images found in Arie_Haan: 1
# Found label directory: Albrecht_Mentz
#   Images found in Albrecht_Mentz: 2
# Found label directory: Jeri_Ryan
#   Images found in Jeri_Ryan: 1
# Found label directory: Jane_Riley
#   Images found in Jane_Riley: 1
# Found label directory: Bode_Miller
#   Images found in Bode_Miller: 2
# Found label directory: Bill_Paxton
#   Images found in Bill_Paxton: 4
# Found label directory: Bobby_Jackson
#   Images found in Bobby_Jackson: 1
# Found label directory: Tommy_Maddox
#   Images found in Tommy_Maddox: 1
# Found label directory: Terrence_Kiel
#   Images found in Terrence_Kiel: 1
# Found label directory: Billy_Beane
#   Images found in Billy_Beane: 1
# Found label directory: Tim_Robbins
#   Images found in Tim_Robbins: 5
# Found label directory: Thomas_Wyman
#   Images found in Thomas_Wyman: 2
# Found label directory: James_Barksdale
#   Images found in James_Barksdale: 1
# Found label directory: David_Hasselhoff
#   Images found in David_Hasselhoff: 1
# Found label directory: Raghad_Saddam_Hussein
#   Images found in Raghad_Saddam_Hussein: 2
# Found label directory: Paul_Coppin
#   Images found in Paul_Coppin: 2
# Found label directory: Craig_OClair
#   Images found in Craig_OClair: 1
# Found label directory: Mack_Brown
#   Images found in Mack_Brown: 2
# Found label directory: Renee_Zellweger
#   Images found in Renee_Zellweger: 17
# Found label directory: Mike_Maroth
#   Images found in Mike_Maroth: 1
# Found label directory: Alexander_Rumyantsev
#   Images found in Alexander_Rumyantsev: 2
# Found label directory: Mike_Martz
#   Images found in Mike_Martz: 7
# Found label directory: Paddy_Torsney
#   Images found in Paddy_Torsney: 1
# Found label directory: Lucio_Angulo
#   Images found in Lucio_Angulo: 1
# Found label directory: Saoud_Al_Faisal
#   Images found in Saoud_Al_Faisal: 1
# Found label directory: Aishwarya_Rai
#   Images found in Aishwarya_Rai: 1
# Found label directory: Chang_Saio-yue
#   Images found in Chang_Saio-yue: 1
# Found label directory: Patrick_Clawsen
#   Images found in Patrick_Clawsen: 1
# Found label directory: James_Spalding
#   Images found in James_Spalding: 1
# Found label directory: Mark_Foley
#   Images found in Mark_Foley: 1
# Found label directory: David_Surrett
#   Images found in David_Surrett: 1
# Found label directory: Clive_Woodward
#   Images found in Clive_Woodward: 1
# Found label directory: Charles_Lebois
#   Images found in Charles_Lebois: 1
# ...
#   Images found in Cheryl_Ford: 1
# Found label directory: Richard_Rodriguez
#   Images found in Richard_Rodriguez: 1
# Found label directory: Dolly_Parton
#   Images found in Dolly_Parton: 2
# Found label directory: Dan_Bartlett
#   Images found in Dan_Bartlett: 1
# Found label directory: Jerry_Seinfeld
#   Images found in Jerry_Seinfeld: 1
# Found label directory: Chip_Burrus
#   Images found in Chip_Burrus: 1
# Found label directory: Rick_Carlisle
#   Images found in Rick_Carlisle: 4
# Found label directory: Grady_Irvin_Jr
#   Images found in Grady_Irvin_Jr: 2
# Found label directory: Binyamin_Ben-Eliezer
#   Images found in Binyamin_Ben-Eliezer: 7
# Found label directory: Steven_Feldman
#   Images found in Steven_Feldman: 1
# Found label directory: Jacqueline_Edwards
#   Images found in Jacqueline_Edwards: 1
# Found label directory: Jeff_Van_Gundy
#   Images found in Jeff_Van_Gundy: 3
# Found label directory: Lee_Byung-woong
#   Images found in Lee_Byung-woong: 1
# Found label directory: Bob_Herz
#   Images found in Bob_Herz: 1
# Found label directory: John_White
#   Images found in John_White: 1
# Found label directory: Frank_Marshall
#   Images found in Frank_Marshall: 1
# Found label directory: Malcolm_Glazer
#   Images found in Malcolm_Glazer: 1
# Found label directory: Rudolph_Holton
#   Images found in Rudolph_Holton: 1
# Found label directory: Christian_Bale
#   Images found in Christian_Bale: 1
# Found label directory: Danny_Elfman
#   Images found in Danny_Elfman: 1
# Found label directory: Charlotte_Casiraghi
#   Images found in Charlotte_Casiraghi: 1
# Found label directory: Carol_Burnett
#   Images found in Carol_Burnett: 2
# Found label directory: Billy_Boyd
#   Images found in Billy_Boyd: 1
# Found label directory: Matt_Herden
#   Images found in Matt_Herden: 1
# Found label directory: Daniel_Montenegro
#   Images found in Daniel_Montenegro: 1
# Found label directory: Tim_Henman
#   Images found in Tim_Henman: 19
# Found label directory: Irina_Yatchenko
#   Images found in Irina_Yatchenko: 1
# Found label directory: Alain_Ducasse
#   Images found in Alain_Ducasse: 1
# Found label directory: Lee_Chang-dong
#   Images found in Lee_Chang-dong: 1
# Found label directory: Tora_Takagi
#   Images found in Tora_Takagi: 1
# Found label directory: Monique_Ferreira
#   Images found in Monique_Ferreira: 1
# Found label directory: Alexander_Losyukov
#   Images found in Alexander_Losyukov: 4
# Found label directory: Pedro_Malan
#   Images found in Pedro_Malan: 5
# Found label directory: Daniel_Patrick_Moynihan
#   Images found in Daniel_Patrick_Moynihan: 1
# Found label directory: Bill_Stein
#   Images found in Bill_Stein: 1
# Found label directory: Flor_Montulo
#   Images found in Flor_Montulo: 2
# Found label directory: Robert_Kocharian
#   Images found in Robert_Kocharian: 5
# Found label directory: Emmanuel_Filiberto
#   Images found in Emmanuel_Filiberto: 1
# Found label directory: Paul_Murphy
#   Images found in Paul_Murphy: 1
# Found label directory: Bob_Guccione
#   Images found in Bob_Guccione: 1
# Found label directory: Ernest_Hollings
#   Images found in Ernest_Hollings: 1
# Found label directory: Markus_Naslund
#   Images found in Markus_Naslund: 2
# Found label directory: Anastasia_Kelesidou
#   Images found in Anastasia_Kelesidou: 1
# Found label directory: Vaclav_Klaus
#   Images found in Vaclav_Klaus: 2
# Found label directory: Roger_Federer
#   Images found in Roger_Federer: 14
# Found label directory: John_Bolton
#   Images found in John_Bolton: 17
# Found label directory: Jennifer_Thompson
#   Images found in Jennifer_Thompson: 2
# Found label directory: George_Pataki
#   Images found in George_Pataki: 5
# Found label directory: Ben_Braun
#   Images found in Ben_Braun: 1
# Found label directory: Gordon_McDonald
#   Images found in Gordon_McDonald: 1
# Found label directory: Matthew_Ouimet
#   Images found in Matthew_Ouimet: 1
# Found label directory: James_Lockhart
#   Images found in James_Lockhart: 1
# Found label directory: Muhammad_Ibrahim_Bilal
#   Images found in Muhammad_Ibrahim_Bilal: 1
# Found label directory: Nikki_Reed
#   Images found in Nikki_Reed: 2
# Found label directory: Darcy_Regier
#   Images found in Darcy_Regier: 1
# Found label directory: Lyudmila_Putin
#   Images found in Lyudmila_Putin: 1
# Found label directory: Mian_Khursheed_Mehmood_Kasuri
#   Images found in Mian_Khursheed_Mehmood_Kasuri: 4
# Found label directory: Saeb_Erekat
#   Images found in Saeb_Erekat: 2
# Found label directory: Cristian_Barros
#   Images found in Cristian_Barros: 1
# Found label directory: Al_Cardenas
#   Images found in Al_Cardenas: 1
# Found label directory: Dario_Camuffo
#   Images found in Dario_Camuffo: 1
# Found label directory: Christine_Rau
#   Images found in Christine_Rau: 1
# Found label directory: Rick_Husband
#   Images found in Rick_Husband: 1
# Found label directory: Julian_Fantino
#   Images found in Julian_Fantino: 1
# Found label directory: Larry_Hahn
#   Images found in Larry_Hahn: 1
# Found label directory: Michael_Caine
#   Images found in Michael_Caine: 4
# Found label directory: Yang_Jianli
#   Images found in Yang_Jianli: 1
# Found label directory: Claudia_Schiffer
#   Images found in Claudia_Schiffer: 3
# Found label directory: Patrick_McEnroe
#   Images found in Patrick_McEnroe: 2
# Found label directory: Sonya_Walger
#   Images found in Sonya_Walger: 1
# Found label directory: Ray_Wasden
#   Images found in Ray_Wasden: 1
# Found label directory: Frank_Shea
#   Images found in Frank_Shea: 1
# Found label directory: Jim_Paxson
#   Images found in Jim_Paxson: 1
# Found label directory: Chuck_Eidson
#   Images found in Chuck_Eidson: 1
# Found label directory: Ronald_White
#   Images found in Ronald_White: 1
# Found label directory: Lydia_Shum
#   Images found in Lydia_Shum: 1
# Found label directory: Steve_Cutler
#   Images found in Steve_Cutler: 1
# Found label directory: Alan_Greenspan
#   Images found in Alan_Greenspan: 5
# Found label directory: John_Fenn
#   Images found in John_Fenn: 1
# Found label directory: Lars_Burgsmuller
#   Images found in Lars_Burgsmuller: 1
# Found label directory: Askar_Akayev
#   Images found in Askar_Akayev: 1
# Found label directory: Amanda_Plumer
#   Images found in Amanda_Plumer: 1
# Found label directory: Maria_Soledad_Alvear_Valenzuela
#   Images found in Maria_Soledad_Alvear_Valenzuela: 5
# Found label directory: Adam_Herbert
#   Images found in Adam_Herbert: 1
# Found label directory: Daniel_Pearl
#   Images found in Daniel_Pearl: 1
# Found label directory: Boris_Jordan
#   Images found in Boris_Jordan: 1
# Found label directory: Maureen_Kanka
#   Images found in Maureen_Kanka: 1
# Found label directory: Colin_Prescot
#   Images found in Colin_Prescot: 1
# Found label directory: Melchor_Cob_Castro
#   Images found in Melchor_Cob_Castro: 1
# Found label directory: Kenneth_Cooper
#   Images found in Kenneth_Cooper: 1
# Found label directory: JP_Suarez
#   Images found in JP_Suarez: 1
# Found label directory: Roman_Coppola
#   Images found in Roman_Coppola: 1
# Found label directory: Daniel_Ortega
#   Images found in Daniel_Ortega: 1
# Found label directory: Kate_Starbird
#   Images found in Kate_Starbird: 1
# Found label directory: Zico
#   Images found in Zico: 3
# Found label directory: Hartmut_Mehdorn
#   Images found in Hartmut_Mehdorn: 1
# Found label directory: Fernando_Hierro
#   Images found in Fernando_Hierro: 1
# Found label directory: Geoff_Dixon
#   Images found in Geoff_Dixon: 1
# Found label directory: Takenori_Kanzaki
#   Images found in Takenori_Kanzaki: 1
# Found label directory: Darryl_McDaniels
#   Images found in Darryl_McDaniels: 1
# Found label directory: Desiree_Lemosi
#   Images found in Desiree_Lemosi: 2
# Found label directory: Bill_King
#   Images found in Bill_King: 1
# Found label directory: Jamie_Lee_Curtis
#   Images found in Jamie_Lee_Curtis: 1
# Found label directory: Raja_Ibrahim
#   Images found in Raja_Ibrahim: 1
# Found label directory: Luke_Smith
#   Images found in Luke_Smith: 1
# Found label directory: Wan_Yanhai
#   Images found in Wan_Yanhai: 1
# Found label directory: Catherine_Zeta-Jones
#   Images found in Catherine_Zeta-Jones: 11
# Found label directory: Jacques_Villeneuve
#   Images found in Jacques_Villeneuve: 1
# Found label directory: David_Canary
#   Images found in David_Canary: 1
# Found label directory: Pascal_Quignard
#   Images found in Pascal_Quignard: 3
# Found label directory: Stacy_Dragila
#   Images found in Stacy_Dragila: 2
# Found label directory: Chakib_Khelil
#   Images found in Chakib_Khelil: 2
# Found label directory: Sue_Wicks
#   Images found in Sue_Wicks: 2
# Found label directory: Alexandre_Herchcovitch
#   Images found in Alexandre_Herchcovitch: 1
# Found label directory: Rob_Niedermayer
#   Images found in Rob_Niedermayer: 1
# Found label directory: Greg_Kinnear
#   Images found in Greg_Kinnear: 1
# Found label directory: Bronson_Arroyo
#   Images found in Bronson_Arroyo: 1
# Found label directory: Tommy_Thompson
#   Images found in Tommy_Thompson: 10
# Found label directory: Ghassan_Elashi
#   Images found in Ghassan_Elashi: 1
# Found label directory: Andres_Manuel_Lopez_Obrador
#   Images found in Andres_Manuel_Lopez_Obrador: 1
# Found label directory: Prince_Naruhito
#   Images found in Prince_Naruhito: 3
# Found label directory: James_Becker
#   Images found in James_Becker: 1
# Found label directory: Chuck_Finley
#   Images found in Chuck_Finley: 1
# Found label directory: Steve_Coterill
#   Images found in Steve_Coterill: 1
# Found label directory: Raul_Ibanez
#   Images found in Raul_Ibanez: 1
# Found label directory: Georgia_Giddings
#   Images found in Georgia_Giddings: 1
# Found label directory: Stephen_Joseph
#   Images found in Stephen_Joseph: 1
# Found label directory: Curtis_Joseph
#   Images found in Curtis_Joseph: 1
# Found label directory: Kent_Robinson
#   Images found in Kent_Robinson: 1
# Found label directory: Leandro_Garcia
#   Images found in Leandro_Garcia: 1
# Found label directory: Rosario_Dawson
#   Images found in Rosario_Dawson: 1
# Found label directory: Hidetoshi_Nakata
#   Images found in Hidetoshi_Nakata: 1
# Found label directory: German_Khan
#   Images found in German_Khan: 1
# Found label directory: Ted_Turner
#   Images found in Ted_Turner: 1
# Found label directory: John_Leguizamo
#   Images found in John_Leguizamo: 1
# Found label directory: Roberto_Cavalli
#   Images found in Roberto_Cavalli: 1
# Found label directory: Greg_Owen
#   Images found in Greg_Owen: 2
# Found label directory: Steve_Backley
#   Images found in Steve_Backley: 2
# Found label directory: Wang_Yi
#   Images found in Wang_Yi: 2
# Found label directory: Svend_Robinson
#   Images found in Svend_Robinson: 1
# Found label directory: Andrei_Nikolishin
#   Images found in Andrei_Nikolishin: 1
# Found label directory: Andy_Benes
#   Images found in Andy_Benes: 1
# Found label directory: Natalia_Verbeke
#   Images found in Natalia_Verbeke: 1
# Found label directory: Mark_Everson
#   Images found in Mark_Everson: 1
# Found label directory: Cristina_Saralegui
#   Images found in Cristina_Saralegui: 2
# Found label directory: Paul_Cerjan
#   Images found in Paul_Cerjan: 1
# Found label directory: Daniel_Coats
#   Images found in Daniel_Coats: 1
# Found label directory: Rainer_Schuettler
#   Images found in Rainer_Schuettler: 5
# Found label directory: Horace_Donovan_Reid
#   Images found in Horace_Donovan_Reid: 1
# Found label directory: MC_Hammer
#   Images found in MC_Hammer: 1
# Found label directory: Paul_Farley
#   Images found in Paul_Farley: 1
# Found label directory: Brad_Brownell
#   Images found in Brad_Brownell: 1
# Found label directory: Glenn_Plummer
#   Images found in Glenn_Plummer: 1
# Found label directory: Selma_Phoenix
#   Images found in Selma_Phoenix: 1
# Found label directory: Pierre_Png
#   Images found in Pierre_Png: 1
# Found label directory: Elisha_Cuthbert
#   Images found in Elisha_Cuthbert: 1
# Found label directory: Luc_Montagnier
#   Images found in Luc_Montagnier: 1
# Found label directory: Jan_Bjoerklund
#   Images found in Jan_Bjoerklund: 1
# Found label directory: Michelle_Yeoh
#   Images found in Michelle_Yeoh: 5
# Found label directory: Carlos_Queiroz
#   Images found in Carlos_Queiroz: 1
# Found label directory: Tim_Pawlenty
#   Images found in Tim_Pawlenty: 1
# Found label directory: Gerard_de_Cortanze
#   Images found in Gerard_de_Cortanze: 1
# Found label directory: Huang_Suey-Sheng
#   Images found in Huang_Suey-Sheng: 1
# Found label directory: Kathy_Gannon
#   Images found in Kathy_Gannon: 1
# Found label directory: Wayne_Newton
#   Images found in Wayne_Newton: 1
# Found label directory: Jimmy_Szymanski
#   Images found in Jimmy_Szymanski: 1
# Found label directory: Bob_Riley
#   Images found in Bob_Riley: 1
# Found label directory: Charles_Schumer
#   Images found in Charles_Schumer: 2
# Found label directory: Derek_King
#   Images found in Derek_King: 1
# Found label directory: Mile_Mrksic
#   Images found in Mile_Mrksic: 1
# Found label directory: Suk_Chung_Hong
#   Images found in Suk_Chung_Hong: 1
# Found label directory: Jerry_Sloan
#   Images found in Jerry_Sloan: 1
# Found label directory: David_Myers
#   Images found in David_Myers: 2
# Found label directory: David_Kelly
#   Images found in David_Kelly: 1
# Found label directory: Tessa_Jowell
#   Images found in Tessa_Jowell: 1
# Found label directory: Kamel_Morjane
#   Images found in Kamel_Morjane: 1
# Found label directory: Andrea_Yates
#   Images found in Andrea_Yates: 1
# Found label directory: Katherine_Harris
#   Images found in Katherine_Harris: 4
# Found label directory: Gloria_Macapagal_Arroyo
#   Images found in Gloria_Macapagal_Arroyo: 44
# Found label directory: Jeff_George
#   Images found in Jeff_George: 1
# Found label directory: Calista_Flockhart
#   Images found in Calista_Flockhart: 6
# Found label directory: Venus_Williams
#   Images found in Venus_Williams: 17
# Found label directory: Garry_Alejano
#   Images found in Garry_Alejano: 1
# Found label directory: Lane_Bryant
#   Images found in Lane_Bryant: 1
# Found label directory: Mark_Lazarus
#   Images found in Mark_Lazarus: 1
# Found label directory: Ahmet_Necdet_Sezer
#   Images found in Ahmet_Necdet_Sezer: 2
# Found label directory: Patrick_Dennehy
#   Images found in Patrick_Dennehy: 1
# Found label directory: Brent_Coles
#   Images found in Brent_Coles: 1
# Found label directory: Luciano_Bovicelli
#   Images found in Luciano_Bovicelli: 1
# Found label directory: Demetrius_Ferraciu
#   Images found in Demetrius_Ferraciu: 2
# Found label directory: Barbara_Roberts
#   Images found in Barbara_Roberts: 1
# Found label directory: Darryl_Stingley
#   Images found in Darryl_Stingley: 1
# Found label directory: Carla_Del_Ponte
#   Images found in Carla_Del_Ponte: 5
# Found label directory: Richard_Butler
#   Images found in Richard_Butler: 2
# Found label directory: Jesse_Helms
#   Images found in Jesse_Helms: 1
# Found label directory: Andrea_De_Cruz
#   Images found in Andrea_De_Cruz: 1
# Found label directory: Linda_Baboolal
#   Images found in Linda_Baboolal: 1
# Found label directory: Tom_Craddick
#   Images found in Tom_Craddick: 4
# Found label directory: Princess_Maxima
#   Images found in Princess_Maxima: 1
# Found label directory: Thad_Matta
#   Images found in Thad_Matta: 1
# Found label directory: Kelly_Ripa
#   Images found in Kelly_Ripa: 1
# Found label directory: Gregory_Hines
#   Images found in Gregory_Hines: 2
# Found label directory: Manuela_Montebrun
#   Images found in Manuela_Montebrun: 1
# Found label directory: Alex_Barros
#   Images found in Alex_Barros: 2
# Found label directory: Rafidah_Aziz
#   Images found in Rafidah_Aziz: 1
# Found label directory: Mike_Thibault
#   Images found in Mike_Thibault: 1
# Found label directory: Sachin_Tendulkar
#   Images found in Sachin_Tendulkar: 1
# Found label directory: Sivan_Klein
#   Images found in Sivan_Klein: 1
# Found label directory: Mark_Komara
#   Images found in Mark_Komara: 1
# Found label directory: Lin_Yi-fu
#   Images found in Lin_Yi-fu: 1
# Found label directory: Jorge_Moreno
#   Images found in Jorge_Moreno: 1
# Found label directory: Ivan_Stambolic
#   Images found in Ivan_Stambolic: 1
# Found label directory: Mike_Farrar
#   Images found in Mike_Farrar: 1
# Found label directory: Laura_Elena_Harring
#   Images found in Laura_Elena_Harring: 1
# Found label directory: Celso_Lafer
#   Images found in Celso_Lafer: 1
# Found label directory: Katie_Wagner
#   Images found in Katie_Wagner: 1
# Found label directory: Deepa_Mehta
#   Images found in Deepa_Mehta: 1
# Found label directory: George_Papandreou
#   Images found in George_Papandreou: 4
# Found label directory: Kenny_Chesney
#   Images found in Kenny_Chesney: 1

# %%
# Define paths and parameters
image_size = (64, 64)  # Resize images to 64x64 pixels
base_path = os.path.join(path, "lfw_funneled")

# %%
# Load images and labels
def load_images_and_labels(base_folder):
    images = []
    labels = []
    for subdir in os.listdir(base_folder):
        subpath = os.path.join(base_folder, subdir)
        if os.path.isdir(subpath):
            for filename in os.listdir(subpath):
                img_path = os.path.join(subpath, filename)
                img = cv2.imread(img_path)
                if img is not None:
                    img = cv2.resize(img, image_size)  # Resize image
                    img = img_to_array(img) / 255.0  # Normalize pixel values
                    images.append(img)
                    labels.append(subdir)  # Use directory name as label
    return np.array(images), labels

# %%
# Load dataset
images, labels = load_images_and_labels(base_path)

# %%
# Encode labels
le = LabelEncoder()
labels_encoded = le.fit_transform(labels)
labels_encoded = to_categorical(labels_encoded)

# %%
# Split dataset into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(images, labels_encoded, test_size=0.2, random_state=42)

# %%
# Build CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(len(le.classes_), activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=2, validation_data=(X_val, y_val), batch_size=32)
# Out:
# Epoch 1/2
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 90s 271ms/step - accuracy: 0.0391 - loss: 7.8164 - val_accuracy: 0.0416 - val_loss: 8.0626
# Epoch 2/2
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 137s 257ms/step - accuracy: 0.0375 - loss: 7.7554 - val_accuracy: 0.0416 - val_loss: 8.1039

# %%
# Evaluate model
print("Validation accuracy:", model.evaluate(X_val, y_val)[1])
# Out:
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.0491 - loss: 8.0430
# Validation accuracy: 0.041556477546691895

# %%
# Apply Dimensionality Reduction using PCA
from sklearn.decomposition import PCA

# Flatten images for PCA
X_train_flat = X_train.reshape(len(X_train), -1)
X_val_flat = X_val.reshape(len(X_val), -1)

# %%
# Apply PCA to reduce dimensions to 100 components
pca = PCA(n_components=100)
X_train_pca = pca.fit_transform(X_train_flat)
X_val_pca = pca.transform(X_val_flat)

# %%
# Convert back to 64x64 (or adapt CNN to accept flattened input)
X_train_pca = X_train_pca.reshape(-1, 10, 10, 1)
X_val_pca = X_val_pca.reshape(-1, 10, 10, 1)

# %%
# Re-train model on reduced data (update input shape to 10x10x1 if required)
model_reduced = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(10, 10, 1)),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(len(le.classes_), activation='softmax')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_reduced.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history_reduced = model_reduced.fit(X_train_pca, y_train, epochs=2, validation_data=(X_val_pca, y_val), batch_size=32)
# Out:
# Epoch 1/2
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.0318 - loss: 8.2968 - val_accuracy: 0.0416 - val_loss: 8.0135
# Epoch 2/2
# 331/331 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.0324 - loss: 7.8246 - val_accuracy: 0.0416 - val_loss: 8.0926

# %%
# Compare accuracy
print("Validation accuracy after dimensionality reduction:", model_reduced.evaluate(X_val_pca, y_val)[1])
# Out:
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.0491 - loss: 8.0183
# Validation accuracy after dimensionality reduction: 0.041556477546691895
